# %% [markdown]
# # Instructions
#
# You are required to perform atleast one or more tasks given below. The drive links will be updated at the earliest. Please write your codes in this jupyter notebook and submit them through before the deadline.
#
# PS :- You can use __Google Colab__ for any of these tasks and they should run fairly quickly even on the free GPU instance on __Google Colab__.

# %% [markdown]
# ## Task 1 : Audio Event Detection
#
# In this task, you have to understand the working of Audio Event Detection (AED) and use PANNs pre-trained model to perform AED on the test audio data. You must evaluate the performance of PANNs model using precision, recall, F1 score and mAP score.
#
# Github repo of PANNs :  https://github.com/qiuqiangkong/panns_inference \
# Test dataset link: https://drive.google.com/drive/folders/1VHQX3GtJlE72CF8x47-OU09DrLtqObTs?usp=drive_link
#
# Test dataset comprises audios in `wav/` folder and corresponding `.tsv` file in `tsv/` folder. The `tsv` file has the following fields:
# - Column 1 : Start_time (in seconds)
# - Column 2 : End_time (in seconds)
# - Column 3 : Label (N- nonspeech region; S- speech region; NS- speech+nonspeech region)

# %%
# !pip install panns-inference
# Out:
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
# !pip install sympy
# Out:
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
# !pip install Cython
# Out:
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
# !ls
# Out:
# Assignment_WinterIntership23_MADHAVlab.ipynb  results  Task1

# %%
import torch

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import librosa
import panns_inference
from panns_inference import AudioTagging, SoundEventDetection, labels
import numpy as np
import re
import pandas as pd
from sklearn.metrics import precision_recall_fscore_support, average_precision_score
from sklearn.preprocessing import label_binarize

# %%
def print_audio_tagging_result(clipwise_output):
    """Visualization of audio tagging result.

    Args:
      clipwise_output: (classes_num,)
    """
    sorted_indexes = np.argsort(clipwise_output)[::-1]

    # Print audio tagging top probabilities
    for k in range(10):
        print('{}: {:.3f}'.format(np.array(labels)[sorted_indexes[k]], 
            clipwise_output[sorted_indexes[k]]))


def plot_sound_event_detection_result(framewise_output):
    """Visualization of sound event detection result. 

    Args:
      framewise_output: (time_steps, classes_num)
    """
    out_fig_path = 'results/sed_result.png'
    os.makedirs(os.path.dirname(out_fig_path), exist_ok=True)

    classwise_output = np.max(framewise_output, axis=0) # (classes_num,)

    idxes = np.argsort(classwise_output)[::-1]
    idxes = idxes[0:5]

    ix_to_lb = {i : label for i, label in enumerate(labels)}
    lines = []
    for idx in idxes:
        line, = plt.plot(framewise_output[:, idx], label=ix_to_lb[idx])
        lines.append(line)

    plt.legend(handles=lines)
    plt.xlabel('Frames')
    plt.ylabel('Probability')
    plt.ylim(0, 1.)
    plt.savefig(out_fig_path)
    print('Save fig to {}'.format(out_fig_path))

# %%
# device = 'cuda' if torch.cuda.is_available() else 'cpu'
# print(device)
# audio_path = 'Task1/audio_1.wav'
# (audio, _) = librosa.core.load(audio_path, sr=32000, mono=True)
# audio = audio[None, :]  # (batch_size, segment_samples)

# print('------ Audio tagging ------')
# at = AudioTagging(checkpoint_path=None, device=device)
# (clipwise_output, embedding) = at.inference(audio)
# """clipwise_output: (batch_size, classes_num), embedding: (batch_size, embedding_size)"""

# print_audio_tagging_result(clipwise_output[0])

# print('------ Sound event detection ------')
# sed = SoundEventDetection(
#     checkpoint_path=None, 
#     device=device, 
#     interpolate_mode='nearest', # 'nearest'
# )
# framewise_output = sed.inference(audio)
# """(batch_size, time_steps, classes_num)"""

# plot_sound_event_detection_result(framewise_output[0])

# %%
# print(labels)

# %%
# import pandas as pd

# ground_truth_path = 'Task1/audio_1.tsv'
# ground_truth = pd.read_csv(ground_truth_path, sep='\t', header=None, names=['Start_time', 'End_time', 'Label'])
# ground_truth = ground_truth.dropna()
# ground_truth

# %%
# (clipwise_output, embedding) = at.inference(audio)
# framewise_output = sed.inference(audio)

# %%
# framewise_output.shape

# %%
# threshold = 0.6  # Adjust this threshold as needed
# binary_predictions = (clipwise_output > threshold).astype(int)
# binary_predictions.shape

# %%
# # Assuming you have ground truth in the form of start and end times
# # Convert ground truth to frame-wise annotations
# frame_rate = int(framewise_output.shape[1] / ground_truth['End_time'].iloc[-1])
# classes = {'n': 0, 's': 2, 'ns': 1}
# ground_truth = ground_truth.sort_values(by='Start_time')

# # Initialize frame_annotations as an empty list

# # Modify the generate_frame_annotations function
# def generate_frame_annotations(start_time, end_time, label, frame_rate, frame_annotations):
#     start_frame = int(start_time * frame_rate)
#     end_frame = int(end_time * frame_rate)
    
#     frame = np.zeros(end_frame - start_frame + 1)
    
#     # Assign label to the corresponding frames
#     frame[:] = classes[re.sub(r'[^ns]', '', label.replace(" ", "").lower())]
    
#     frame_annotations.extend(frame)

# frame_annotations=[]
# # Extend the frame_annotations list with the arrays generated by apply
# ground_truth.apply(lambda row: generate_frame_annotations(row['Start_time'], row['End_time'], row['Label'], frame_rate, frame_annotations), axis=1)
# print(len(frame_annotations))

# # Generate random indices to delete
# indices_to_delete = np.random.choice(len(frame_annotations), len(frame_annotations) - framewise_output.shape[1], replace=False)

# # Create a new array without the selected indices
# frame_annotations = np.delete(frame_annotations, indices_to_delete, axis=0)
# print(len(frame_annotations))

# # Assuming you have framewise_output from your model
# # Convert it to binary predictions using a threshold
# threshold1 = 0.4  # Adjust this threshold as needed
# threshold2 = 0.6  # Adjust this threshold as needed

# # Apply two thresholds
# binary_predictions = np.zeros_like(framewise_output[0, :, 0], dtype=int)
# binary_predictions[(framewise_output[0, :, 0] > threshold2)] = 2
# binary_predictions[(framewise_output[0, :, 0] <= threshold2) & (framewise_output[0, :, 0] > threshold1)] = 1
# binary_predictions[(framewise_output[0, :, 0] <= threshold1)] = 0

# # Flatten ground truth and predictions for evaluation
# ground_truth_flat = frame_annotations
# predictions_flat = binary_predictions.flatten()

# # Calculate precision, recall, F1 score
# matrix1 = precision_recall_fscore_support(ground_truth_flat, binary_predictions, labels=[0, 1, 2])

# print(precision)

# %%
def generate_frame_annotations(start_time, end_time, label, frame_rate, frame_annotations):
    start_frame = int(start_time * frame_rate)
    end_frame = int(end_time * frame_rate)
    
    frame = np.zeros(end_frame - start_frame + 1)
    
    # Assign label to the corresponding frames
    frame[:] = classes[re.sub(r'[^ns]', '', label.replace(" ", "").lower())]
    
    frame_annotations.extend(frame)

# %%
ap=[]
ar=[]
af1=[]
for i in range(1,5):
#     device = 'cuda' if torch.cuda.is_available() else 'cpu'
    device='cpu'
    print(device)
    audio_path = f'Task1/audio_{i}.wav'
    (audio, _) = librosa.core.load(audio_path, sr=32000, mono=True)
    audio = audio[None, :]  # (batch_size, segment_samples)

    print('------ Audio tagging ------')
    at = AudioTagging(checkpoint_path=None, device=device)
    (clipwise_output, embedding) = at.inference(audio)
    """clipwise_output: (batch_size, classes_num), embedding: (batch_size, embedding_size)"""

    print_audio_tagging_result(clipwise_output[0])

    print('------ Sound event detection ------')
    sed = SoundEventDetection(
        checkpoint_path=None, 
        device=device, 
        interpolate_mode='nearest', # 'nearest'
    )
    framewise_output = sed.inference(audio)
    """(batch_size, time_steps, classes_num)"""

    plot_sound_event_detection_result(framewise_output[0])
    ground_truth_path = f'Task1/audio_{i}.tsv'
    ground_truth = pd.read_csv(ground_truth_path, sep='\t', header=None, names=['Start_time', 'End_time', 'Label'])
    ground_truth = ground_truth.dropna()
    frame_rate = int(framewise_output.shape[1] / ground_truth['End_time'].iloc[-1])
    classes = {'n': 0, 's': 2, 'ns': 1}
    ground_truth = ground_truth.sort_values(by='Start_time')
    frame_annotations=[]
    # Extend the frame_annotations list with the arrays generated by apply
    ground_truth.apply(lambda row: generate_frame_annotations(row['Start_time'], row['End_time'], row['Label'], frame_rate, frame_annotations), axis=1)
    print(len(frame_annotations))

    # Generate random indices to delete
    indices_to_delete = np.random.choice(len(frame_annotations), len(frame_annotations) - framewise_output.shape[1], replace=False)

    # Create a new array without the selected indices
    frame_annotations = np.delete(frame_annotations, indices_to_delete, axis=0)
    print(len(frame_annotations))

    # Assuming you have framewise_output from your model
    # Convert it to binary predictions using a threshold
    threshold1 = 0.4  # Adjust this threshold as needed
    threshold2 = 0.5  # Adjust this threshold as needed

    # Apply two thresholds
    binary_predictions = np.zeros_like(framewise_output[0, :, 0], dtype=int)
    binary_predictions[(framewise_output[0, :, 0] > threshold2)] = 2
    binary_predictions[(framewise_output[0, :, 0] <= threshold2) & (framewise_output[0, :, 0] > threshold1)] = 1
    binary_predictions[(framewise_output[0, :, 0] <= threshold1)] = 0

    # Flatten ground truth and predictions for evaluation
    ground_truth_flat = frame_annotations
    predictions_flat = binary_predictions.flatten()

    # Calculate precision, recall, F1 score
    matrix1 = precision_recall_fscore_support(ground_truth_flat, binary_predictions, labels=[0, 1, 2])
    ap.append(matrix1[0].mean())
    ar.append(matrix1[1].mean())
    af1.append(matrix1[2].mean())
    print("Average Precicion", ap)
    print("Average Recall", ar)
    print("Average F1 Score",af1)

print("mAP", sum(ap)/len(ap))
print("mean average recall", sum(ar)/len(ar))
print("Mean f1 score", sum(af1)/len(af1))
# Out:
# cpu
# ------ Audio tagging ------
# Checkpoint path: /home/suryansh/panns_data/Cnn14_mAP=0.431.pth
# Using CPU.
# Speech: 0.732
# Music: 0.622
# Animal: 0.071
# Outside, rural or natural: 0.037
# Fart: 0.036
# Vehicle: 0.027
# Domestic animals, pets: 0.025
# Brass instrument: 0.019
# Vehicle horn, car horn, honking: 0.018
# Dial tone: 0.017
# ------ Sound event detection ------
# Checkpoint path: /home/suryansh/panns_data/Cnn14_DecisionLevelMax.pth
# Using CPU.
# Save fig to results/sed_result.png
# 154001
# 153549
# Average Precicion [0.5086304892815446]
# Average Recall [0.46569230995545086]
# Average F1 Score [0.4552153553008882]
# cpu
# ------ Audio tagging ------
# Checkpoint path: /home/suryansh/panns_data/Cnn14_mAP=0.431.pth
# Using CPU.
# Music: 0.663
# Speech: 0.616
# Boing: 0.041
# Inside, small room: 0.040
# Bird: 0.028
# Outside, rural or natural: 0.022
# Musical instrument: 0.020
# Bird vocalization, bird call, bird song: 0.019
# Chirp, tweet: 0.017
# Thunk: 0.017
# ...

# %%
best_th1 = 0
best_th2 = 0.5
best_r=0
best_p=0
d_min = 1
ps=[]
rs=[]
for threshold1 in np.arange(0,0.5,0.01):
  for threshold2 in np.arange(0.5,1,0.01):
    binary_predictions = np.zeros_like(framewise_output[0, :, 0], dtype=int)
    binary_predictions[(framewise_output[0, :, 0] > threshold2)] = 2
    binary_predictions[(framewise_output[0, :, 0] <= threshold2) & (framewise_output[0, :, 0] > threshold1)] = 1
    binary_predictions[(framewise_output[0, :, 0] <= threshold1)] = 0

    # Flatten ground truth and predictions for evaluation
    ground_truth_flat = frame_annotations
    predictions_flat = binary_predictions.flatten()

    # Calculate precision, recall, F1 score
    matrix1 = precision_recall_fscore_support(ground_truth_flat, binary_predictions, labels=[0, 1, 2])
    ap.append(matrix1[0].mean())
    ar.append(matrix1[1].mean())
    af1.append(matrix1[2].mean())
    print("Average Precicion", ap)
    print("Average Recall", ar)
    print("Average F1 Score",af1)

print("mAP", sum(ap)/len(ap))
print("mean average recall", sum(ar)/len(ar))
print("Mean f1 score", sum(af1)/len(af1))

# %% [markdown]
# ## Task 2 : ESPnet Automatic Speech Recognition (ASR) model training
#
# In this task, you have to install ESPnet, a popular speech processing toolkit and train a neural network based ASR model on AN4 dataset.
#
# Steps to install ESPnet on your local system are : https://drive.google.com/file/d/1ln3nrfxh5cq5_cTQWTkpOTnXeepypJgr/view?usp=sharing \
# Steps to install ESPnet on __Google colab__ are:
#
# ```
# !git clone --depth 5 https://github.com/espnet/espnet
# # It takes 30 seconds
# %cd /content/espnet/tools
# !./setup_anaconda.sh anaconda espnet 3.9
# # It may take ~8 minutes
# %cd /content/espnet/tools
# !make CUDA_VERSION=10.2
# ```
# Please follow and replicate the steps of the ESPnet Speech Recognition tutorial.
# Training tutorial for ESPnet AN4 : https://espnet.github.io/espnet/notebook/espnet2_tutorial_2021_CMU_11751_18781.html#Run-a-recipe-example
#
# Please follow the tutorial and run the recipe until `Stage 13`.

# %%
# !git clone --depth 5 https://github.com/espnet/espnet
# It takes 30 seconds
# %cd espnet/tools
# !./setup_anaconda.sh anaconda espnet 3.9
# It may take ~8 minutes
# %cd /espnet/tools
# !make CUDA_VERSION=10.2
# Out:
# fatal: destination path 'espnet' already exists and is not an empty directory.
# /home/suryansh/MADHAV_task_1/espnet/tools
# --2023-11-16 01:42:47--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 120771089 (115M) [application/x-sh]
# Saving to: ‘Miniconda3-latest-Linux-x86_64.sh’
#
# Miniconda3-latest-L 100%[===================>] 115.18M  9.21MB/s    in 12s
#
# 2023-11-16 01:42:59 (9.88 MB/s) - ‘Miniconda3-latest-Linux-x86_64.sh’ saved [120771089/120771089]
#
# PREFIX=/home/suryansh/MADHAV_task_1/espnet/tools/anaconda
# Unpacking payload ...
#
# Installing base environment...
#
#
# ...
#
#
# ...
#
# Preparing transaction: done
# Executing transaction: done
# installation finished.
#
# ...

# %%
# !git clone --depth 1 https://github.com/kaldi-asr/kaldi
# Out:
# Cloning into 'kaldi'...
# remote: Enumerating objects: 7681, done.
# remote: Counting objects: 100% (7681/7681), done.
# remote: Compressing objects: 100% (5235/5235), done.
# remote: Total 7681 (delta 2452), reused 4333 (delta 2017), pack-reused 0
# Receiving objects: 100% (7681/7681), 12.70 MiB | 2.76 MiB/s, done.
# Resolving deltas: 100% (2452/2452), done.

# %%
# %cd ..
# %cd egs2/an4/asr1
# !ls
# Out:
# /home/suryansh/MADHAV_task_1/espnet
# /home/suryansh/MADHAV_task_1/espnet/egs2/an4/asr1
# asr.sh	conf   local	pyscripts  run.sh   steps
# cmd.sh	db.sh  path.sh	README.md  scripts  utils

# %% [markdown]
# ### Stage 1: Data preparation for training, validation, and evaluation data

# %%
# !./asr.sh --stage 1 --stop_stage 1 --train_set train_nodev --valid_set train_dev --test_sets "train_dev test"
# Out:
# 2023-11-16T02:40:48 (asr.sh:283:main) ./asr.sh --stage 1 --stop_stage 1 --train_set train_nodev --valid_set train_dev --test_sets train_dev test
# 2023-11-16T02:40:48 (asr.sh:321:main) Info: The valid_set 'train_dev' is included in the test_sets. '--eval_valid_set true' is set and 'train_dev' is removed from the test_sets
# 2023-11-16T02:40:48 (asr.sh:565:main) Skipped stages:  9 14 15 16
# 2023-11-16T02:40:48 (asr.sh:572:main) Stage 1: Data preparation for data/train_nodev, data/train_dev, etc.
# 2023-11-16T02:40:48 (data.sh:23:main) local/data.sh
# 2023-11-16T02:40:48 (data.sh:39:main) stage 1: Data Download
# local/download_and_untar.sh: an4 directory already exists in ./downloads
# 2023-11-16T02:40:48 (data.sh:49:main) stage 2: Data preparation
# utils/subset_data_dir.sh: reducing #utt from 948 to 100
# utils/subset_data_dir.sh: reducing #utt from 948 to 848
# 2023-11-16T02:40:49 (data.sh:72:main) Successfully finished. [elapsed=1s]
# ...

# %%
# !ls data
# Out:
# test  token_list  train  train_dev  train_nodev

# %%
# !ls -1 data/train_nodev/
# Out:
# spk2utt
# text
# utt2spk
# wav.scp

# %% [markdown]
# ### Stage 2: Speed perturbation

# %%
# !./asr.sh --stage 2 --stop_stage 2 --train_set train_nodev --valid_set train_dev --test_sets "train_dev test" --speed_perturb_factors "0.9 1.0 1.1"
# Out:
# 2023-11-16T02:40:49 (asr.sh:283:main) ./asr.sh --stage 2 --stop_stage 2 --train_set train_nodev --valid_set train_dev --test_sets train_dev test --speed_perturb_factors 0.9 1.0 1.1
# 2023-11-16T02:40:49 (asr.sh:321:main) Info: The valid_set 'train_dev' is included in the test_sets. '--eval_valid_set true' is set and 'train_dev' is removed from the test_sets
# 2023-11-16T02:40:49 (asr.sh:565:main) Skipped stages:  9 14 15 16
# 2023-11-16T02:40:49 (asr.sh:580:main) Stage 2: Speed perturbation: data/train_nodev -> data/train_nodev_sp
# text
# utt2lang
# text
# scripts/utils/perturb_data_dir_speed.sh: generated speed-perturbed version of data in data/train_nodev, in data/train_nodev_sp0.9
# fix_data_dir.sh: kept all 848 utterances.
# fix_data_dir.sh: old files are kept in data/train_nodev_sp0.9/.backup
# utils/validate_data_dir.sh: Successfully validated data-directory data/train_nodev_sp0.9
# text
# utt2lang
# text
# ...

# %% [markdown]
# ### Stage 3: Format wav.scp: data/ -> dump/raw

# %%
# 30 seconds
# !./asr.sh --stage 3 --stop_stage 3 --train_set train_nodev --valid_set train_dev --test_sets "train_dev test" --nj 4
# Out:
# 2023-11-16T02:40:50 (asr.sh:283:main) ./asr.sh --stage 3 --stop_stage 3 --train_set train_nodev --valid_set train_dev --test_sets train_dev test --nj 4
# 2023-11-16T02:40:50 (asr.sh:321:main) Info: The valid_set 'train_dev' is included in the test_sets. '--eval_valid_set true' is set and 'train_dev' is removed from the test_sets
# 2023-11-16T02:40:50 (asr.sh:565:main) Skipped stages:  9 14 15 16
# 2023-11-16T02:40:50 (asr.sh:615:main) Stage 3: Format wav.scp: data/ -> dump/raw
# utils/copy_data_dir.sh: copied data from data/train_nodev to dump/raw/org/train_nodev
# utils/validate_data_dir.sh: Successfully validated data-directory dump/raw/org/train_nodev
# 2023-11-16T02:40:51 (format_wav_scp.sh:46:main) scripts/audio/format_wav_scp.sh --nj 4 --cmd run.pl --audio-format flac --fs 16k --multi-columns-input false --multi-columns-output false data/train_nodev/wav.scp dump/raw/org/train_nodev
# 2023-11-16T02:40:51 (format_wav_scp.sh:118:main) [info]: without segments
# ...

# %% [markdown]
# ### Stage 4: Remove long/short data: dump/raw/org -> dump/raw

# %%
# !./asr.sh --stage 4 --stop_stage 4 --train_set train_nodev --valid_set train_dev --test_sets "train_dev test"
# Out:
# 2023-11-16T02:40:55 (asr.sh:283:main) ./asr.sh --stage 4 --stop_stage 4 --train_set train_nodev --valid_set train_dev --test_sets train_dev test
# 2023-11-16T02:40:55 (asr.sh:321:main) Info: The valid_set 'train_dev' is included in the test_sets. '--eval_valid_set true' is set and 'train_dev' is removed from the test_sets
# 2023-11-16T02:40:55 (asr.sh:565:main) Skipped stages:  9 14 15 16
# 2023-11-16T02:40:55 (asr.sh:800:main) Stage 4: Remove long/short data: dump/raw/org -> dump/raw
# utils/copy_data_dir.sh: copied data from dump/raw/org/train_nodev to dump/raw/train_nodev
# utils/validate_data_dir.sh: Successfully validated data-directory dump/raw/train_nodev
# fix_data_dir.sh: kept all 848 utterances.
# fix_data_dir.sh: old files are kept in dump/raw/train_nodev/.backup
# utils/copy_data_dir.sh: copied data from dump/raw/org/train_dev to dump/raw/train_dev
# utils/validate_data_dir.sh: Successfully validated data-directory dump/raw/train_dev
# ...

# %% [markdown]
# ### Stage 5: Generate token_list from dump/raw/train_nodev/text using BPE.

# %%
# !./asr.sh --stage 5 --stop_stage 5 --train_set train_nodev --valid_set train_dev --test_sets "train_dev test"
# Out:
# 2023-11-16T02:40:55 (asr.sh:283:main) ./asr.sh --stage 5 --stop_stage 5 --train_set train_nodev --valid_set train_dev --test_sets train_dev test
# 2023-11-16T02:40:56 (asr.sh:321:main) Info: The valid_set 'train_dev' is included in the test_sets. '--eval_valid_set true' is set and 'train_dev' is removed from the test_sets
# 2023-11-16T02:40:56 (asr.sh:565:main) Skipped stages:  9 14 15 16
# 2023-11-16T02:40:56 (asr.sh:878:main) Stage 5: Generate token_list from dump/raw/org/train_nodev/text using BPE
# sentencepiece_trainer.cc(177) LOG(INFO) Running command: --input=data/token_list/bpe_unigram30/train.txt --vocab_size=30 --model_type=unigram --model_prefix=data/token_list/bpe_unigram30/bpe --character_coverage=1.0 --input_sentence_size=100000000
# sentencepiece_trainer.cc(77) LOG(INFO) Starts training with :
# trainer_spec {
#   input: data/token_list/bpe_unigram30/train.txt
#   input_format:
#   model_prefix: data/token_list/bpe_unigram30/bpe
#   model_type: UNIGRAM
# ...

# %%
# !cat data/token_list/bpe_unigram30/tokens.txt
# Out:
# <blank>
# <unk>
# ▁
# T
# E
# O
# R
# Y
# A
# H
# U
# S
# I
# F
# B
# L
# P
# D
# G
# M
# C
# V
# X
# J
# K
# Z
# W
# N
# Q
# <sos/eos>

# %% [markdown]
# ### Stage 10: ASR collect stats: train_set=dump/raw/train_nodev, valid_set=dump/raw/train_dev

# %%
# 18 seconds
# !./asr.sh --stage 10 --stop_stage 10 --train_set train_nodev --valid_set train_dev --test_sets "train_dev test" --nj 4
# Out:
# 2023-11-16T02:40:56 (asr.sh:283:main) ./asr.sh --stage 10 --stop_stage 10 --train_set train_nodev --valid_set train_dev --test_sets train_dev test --nj 4
# 2023-11-16T02:40:56 (asr.sh:321:main) Info: The valid_set 'train_dev' is included in the test_sets. '--eval_valid_set true' is set and 'train_dev' is removed from the test_sets
# 2023-11-16T02:40:56 (asr.sh:565:main) Skipped stages:  9 14 15 16
# 2023-11-16T02:40:56 (asr.sh:1190:main) Stage 10: ASR collect stats: train_set=dump/raw/train_nodev, valid_set=dump/raw/train_dev
# 2023-11-16T02:40:56 (asr.sh:1241:main) Generate 'exp/asr_stats_raw_bpe30/run.sh'. You can resume the process from stage 10 using this script
# 2023-11-16T02:40:56 (asr.sh:1245:main) ASR collect-stats started... log: 'exp/asr_stats_raw_bpe30/logdir/stats.*.log'
# run.pl: 4 / 4 failed, log is in exp/asr_stats_raw_bpe30/logdir/stats.*.log
# ...

# %% [markdown]
# ### Stage 11: ASR Training: train_set=dump/raw/train_nodev, valid_set=dump/raw/train_dev

# %%
# It would take 20-30 min.
# !./asr.sh --stage 11 --stop_stage 11 --train_set train_nodev --valid_set train_dev --test_sets "train_dev test" --ngpu 1
# Out:
# 2023-11-16T02:44:20 (asr.sh:283:main) ./asr.sh --stage 11 --stop_stage 11 --train_set train_nodev --valid_set train_dev --test_sets train_dev test --ngpu 1
# 2023-11-16T02:44:20 (asr.sh:321:main) Info: The valid_set 'train_dev' is included in the test_sets. '--eval_valid_set true' is set and 'train_dev' is removed from the test_sets
# 2023-11-16T02:44:20 (asr.sh:565:main) Skipped stages:  9 14 15 16
# 2023-11-16T02:44:20 (asr.sh:1309:main) Stage 11: ASR Training: train_set=dump/raw/train_nodev, valid_set=dump/raw/train_dev
# 2023-11-16T02:44:20 (asr.sh:1408:main) Generate 'exp/asr_train_raw_bpe30/run.sh'. You can resume the process from stage 11 using this script
# 2023-11-16T02:44:20 (asr.sh:1412:main) ASR training started... log: 'exp/asr_train_raw_bpe30/train.log'
# ...

# %% [markdown]
# ### Stage 12: Decoding: training_dir=exp/asr_train_raw_bpe30

# %%
# It would take ~10 minutes
# !./asr.sh --inference_nj 4 --stage 12 --stop_stage 12 --train_set train_nodev --valid_set train_dev --test_sets "train_dev test" --use_lm false
# Out:
# 2023-11-16T02:45:34 (asr.sh:283:main) ./asr.sh --inference_nj 4 --stage 12 --stop_stage 12 --train_set train_nodev --valid_set train_dev --test_sets train_dev test --use_lm false
# 2023-11-16T02:45:35 (asr.sh:321:main) Info: The valid_set 'train_dev' is included in the test_sets. '--eval_valid_set true' is set and 'train_dev' is removed from the test_sets
# 2023-11-16T02:45:35 (asr.sh:565:main) Skipped stages:  6 7 8 9 14 15 16
# 2023-11-16T02:45:35 (asr.sh:1481:main) Stage 12: Decoding: training_dir=exp/asr_train_raw_bpe30
# 2023-11-16T02:45:35 (asr.sh:1509:main) Generate 'exp/asr_train_raw_bpe30/inference_asr_model_valid.acc.ave/run.sh'. You can resume the process from stage 12 using this script
# 2023-11-16T02:45:35 (asr.sh:1574:main) Decoding started... log: 'exp/asr_train_raw_bpe30/inference_asr_model_valid.acc.ave/org/train_dev/logdir/asr_inference.*.log'
# ...

# %% [markdown]
# ### Stage 13: Scoring

# %%
# !./asr.sh --stage 13 --stop_stage 13 --train_set train_nodev --valid_set train_dev --test_sets "train_dev test" --use_lm false
# Out:
# 2023-11-16T02:46:26 (asr.sh:283:main) ./asr.sh --stage 13 --stop_stage 13 --train_set train_nodev --valid_set train_dev --test_sets train_dev test --use_lm false
# 2023-11-16T02:46:26 (asr.sh:321:main) Info: The valid_set 'train_dev' is included in the test_sets. '--eval_valid_set true' is set and 'train_dev' is removed from the test_sets
# 2023-11-16T02:46:26 (asr.sh:565:main) Skipped stages:  6 7 8 9 14 15 16
# 2023-11-16T02:46:26 (asr.sh:1622:main) Stage 13: Scoring
# /home/suryansh/MADHAV_task_1/espnet/tools/anaconda/envs/espnet/bin/python3 /home/suryansh/MADHAV_task_1/espnet/espnet2/bin/tokenize_text.py -f 2- --input - --output - --cleaner none --token_type char --non_linguistic_symbols none --remove_non_linguistic_symbols true
# ./asr.sh: line 1684: exp/asr_train_raw_bpe30/inference_asr_model_valid.acc.ave/org/train_dev/text: No such file or directory
# ...

# %% [markdown]
# ### We can run all the stages together using !cat run.sh
# run.sh can call asr.sh, which completes the entire speech recognition experiments, including data preparation, training, inference, and scoring. They are based on separate stages (totally 15 stages).

# %%
# !cat run.sh
# Out:
# #!/usr/bin/env bash
# # Set bash to 'debug' mode, it will exit on :
# # -e 'error', -u 'undefined variable', -o ... 'error in pipeline', -x 'print commands',
# set -e
# set -u
# set -o pipefail
#
# ./asr.sh \
#     --lang en \
#     --asr_config conf/train_asr_transformer.yaml \
#     --inference_config conf/decode_asr.yaml \
#     --lm_config conf/train_lm.yaml \
#     --speed_perturb_factors "0.9 1.0 1.1" \
#     --train_set train_nodev \
#     --valid_set train_dev \
#     --test_sets "train_dev test" \
#     --bpe_train_text "dump/raw/train_nodev_sp/text" \
#     --lm_train_text "data/train_nodev_sp/text" "$@"

# %%
# !./run.sh
# Out:
# 2023-11-16T02:49:11 (asr.sh:283:main) ./asr.sh --lang en --asr_config conf/train_asr_transformer.yaml --inference_config conf/decode_asr.yaml --lm_config conf/train_lm.yaml --speed_perturb_factors 0.9 1.0 1.1 --train_set train_nodev --valid_set train_dev --test_sets train_dev test --bpe_train_text dump/raw/train_nodev_sp/text --lm_train_text data/train_nodev_sp/text
# 2023-11-16T02:49:11 (asr.sh:321:main) Info: The valid_set 'train_dev' is included in the test_sets. '--eval_valid_set true' is set and 'train_dev' is removed from the test_sets
# 2023-11-16T02:49:11 (asr.sh:565:main) Skipped stages:  9 14 15 16
# 2023-11-16T02:49:11 (asr.sh:572:main) Stage 1: Data preparation for data/train_nodev, data/train_dev, etc.
# 2023-11-16T02:49:11 (data.sh:23:main) local/data.sh
# 2023-11-16T02:49:11 (data.sh:39:main) stage 1: Data Download
# local/download_and_untar.sh: an4 directory already exists in ./downloads
# 2023-11-16T02:49:11 (data.sh:49:main) stage 2: Data preparation
# ...

# %% [markdown]
# ## Task 3: Speech-to-Text conversion using ESPnet pre-trained model
#
# In this task, you are required to use a pretrained model and perform ASR inference using it to convert the given audio files to text.
#
# Please follow the steps above to install ESPnet on __Google Colab__ or your local machine.
#
# Please follow the tutorial : https://espnet.github.io/espnet/notebook/espnet2_tutorial_2021_CMU_11751_18781.html#Run-an-inference-example
#
# Run inference on the ENGLISH test audio files shared in : https://drive.google.com/file/d/1ln3nrfxh5cq5_cTQWTkpOTnXeepypJgr/view?usp=sharing
#
# Report WER and CER on these test files using `torchmetrics` library.

# %%
# !pip install -q espnet_model_zoo

# %%
#@title Choose English ASR model { run: "auto" }

lang = 'en'
fs = 16000 #@param {type:"integer"}
tag = 'Shinji Watanabe/spgispeech_asr_train_asr_conformer6_n_fft512_hop_length256_raw_en_unnorm_bpe5000_valid.acc.ave' #@param ["Shinji Watanabe/spgispeech_asr_train_asr_conformer6_n_fft512_hop_length256_raw_en_unnorm_bpe5000_valid.acc.ave", "kamo-naoyuki/librispeech_asr_train_asr_conformer6_n_fft512_hop_length256_raw_en_bpe5000_scheduler_confwarmup_steps40000_optim_conflr0.0025_sp_valid.acc.ave"] {type:"string"}

# %%
import time
import torch
import string
from espnet_model_zoo.downloader import ModelDownloader
from espnet2.bin.asr_inference import Speech2Text


d = ModelDownloader()
# It may takes a while to download and build models
speech2text = Speech2Text(
    **d.download_and_unpack(tag),
    device="cuda",
    minlenratio=0.0,
    maxlenratio=0.0,
    ctc_weight=0.3,
    beam_size=10,
    batch_size=0,
    nbest=1
)

def text_normalizer(text):
    text = text.upper()
    return text.translate(str.maketrans('', '', string.punctuation))
# Out:
# WARNING:root:Using legacy_rel_pos and it will be deprecated in the future.
# WARNING:root:Using legacy_rel_selfattn and it will be deprecated in the future.

# %%
# !ls
# Out:
# Assignment_WinterIntership23_MADHAVlab.ipynb  espnet  results  Task1  Task3

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %%
import pandas as pd
import soundfile
import librosa.display
from IPython.display import display, Audio
import matplotlib.pyplot as plt
import time

col_names=['path', 'text', 'time', 'sr']
egs = pd.read_csv("Task3/metadata_test_clean.tsv", sep="\t", names=col_names, header=None)
egs=egs[:500]
preds=[]
target=[]
for index, row in egs.iterrows():
    start_time = time.time()
    speech, rate = soundfile.read("Task3/" + row["path"].replace('originals/', ''))
    assert fs == int(row["sr"])
    nbests = speech2text(speech)

    text, *_ = nbests[0]
# Uncomment to see details of each prediction
#     print(f"Input Speech: ESPNet_asr_egs/{row['path']}")
    # let us listen to samples
#     display(Audio(speech, rate=rate))
#     librosa.display.waveshow(speech, sr=rate, color="blue")
#     plt.show()
#     print(f"Reference text: {text_normalizer(row['text'])}")
    target.append(text_normalizer(row['text']))
#     print(f"ASR hypothesis: {text_normalizer(text)}")
    preds.append(text_normalizer(text))
    print(index,"/500")
    elapsed_time = time.time() - start_time
    print(f"Time taken: {elapsed_time:.2f} seconds")
# Out:
# /home/suryansh/anaconda3/lib/python3.11/site-packages/espnet/nets/ctc_prefix_score.py:323: RuntimeWarning: invalid value encountered in logaddexp
#   r_sum = self.xp.logaddexp(
# 0 /500
# Time taken: 1.48 seconds
# 1 /500
# Time taken: 5.05 seconds
# 2 /500
# Time taken: 2.14 seconds
# 3 /500
# Time taken: 4.62 seconds
# 4 /500
# Time taken: 4.32 seconds
# 5 /500
# Time taken: 2.18 seconds
# 6 /500
# Time taken: 2.01 seconds
# 7 /500
# Time taken: 5.02 seconds
# 8 /500
# Time taken: 1.74 seconds
# 9 /500
# Time taken: 2.37 seconds
# 10 /500
# Time taken: 0.95 seconds
# 11 /500
# Time taken: 1.16 seconds
# 12 /500
# Time taken: 1.45 seconds
# 13 /500
# Time taken: 1.02 seconds
# 14 /500
# Time taken: 1.10 seconds
# 15 /500
# Time taken: 1.07 seconds
# 16 /500
# Time taken: 2.39 seconds
# 17 /500
# Time taken: 1.68 seconds
# 18 /500
# Time taken: 5.35 seconds
# 19 /500
# Time taken: 1.04 seconds
# 20 /500
# Time taken: 4.92 seconds
# 21 /500
# Time taken: 10.87 seconds
# 22 /500
# ...

# %%
# import pandas as pd
# import soundfile
# import librosa.display
# from IPython.display import display, Audio
# import matplotlib.pyplot as plt
# import time

# speech, rate = soundfile.read("../Downloads/voice1.ogg")
# nbests = speech2text(speech)

# text, *_ = nbests[0]
# # let us listen to samples
# display(Audio(speech, rate=rate))
# librosa.display.waveshow(speech, sr=rate, color="blue")
# plt.show()
# print(f"ASR hypothesis: {text_normalizer(text)}")

# %%
print(preds[:10])
print(target[:10])
# Out:
# ['SHE WAS TIRED OF OTHER THINGS', 'SHE TRIED THIS MORNING AN ERROR OR 2 ON THE PNO SAYING A SIMPLE SONG AND A SWEEP BUT SLIGHTLY METALLIC AND THEN SEEDING HERSELF BY THE OPEN WINDOW RED PHILIPS PLATTER', 'WELL MOTHER STOOD THE YOUNG STUDENT LOOKING AT WHAT THE SHADED IN PATIENTS', 'I HOPE HE TOLD THE ELDERLY THAT FATHER AND I ARE RESPONSIBLE FOR THE PANEL AND THAT MUCH OF THE LUMPS MUSIC HE IS NEVER IN THE ROOM WHEN IT IS PLAYED', 'I HEARD FATHER TILT BECAUSE OF AN ABNORMAL THAT HE WAS WHIPPED SO OFTEN FOR WHISTLING WHEN HE WAS A BOY THAT HE WAS DETERMINED TO HAVE WHAT COMPENSATION HE COULD GET', 'TAIWANS GREATLY TRIMMED ROOTS AND ALL THE IRRIGATIONS', 'IS THAT FATHER WILLING THEY SHOULD GO AWAY TO A SCHOOL OF THE WORLDS PEOPLE', 'I HAVE NOT ASKED HIM REREPLIED WITH THE LOOK THAT MIGHT IMPLY THAT SHE WAS ONE OF THOSE TO DETERMINE THE LITTLE BODIES WHO FIRST MADE UP THEIR OWN MIND AND THEN COMPELLED OTHERS TO MAKE UP THEIRS IN ACCORDANCE WITH THEIRS', 'MUTHER IM GOING TO STUDY THE MED
# ...

# %%
# !pip install torchmetrics

# %%
from torchmetrics.text import CharErrorRate, WordErrorRate
cer = CharErrorRate()
print("CER:", cer(preds, target))
wer = WordErrorRate()
print("WER:", wer(preds, target))
# Out:
# CER: tensor(0.1703)
# WER: tensor(0.2927)
